# %% [markdown]
# # model building

# %% [markdown]
# # 1.Select the ml model

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %% [markdown]
# # 2.Prepare X and y

# %%
import pandas as pd


# Load dataset
df = pd.read_csv(r"C:\Users\sp719\OneDrive\Desktop\project\ipl.csv")
# Out:
# C:\Users\sp719\AppData\Local\Temp\ipykernel_6120\835701913.py:5: DtypeWarning: Columns (0: season, 1: result_margin) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\sp719\OneDrive\Desktop\project\ipl.csv")

# %%
features = [
    'runs_scored',
    'extras',
    'current_score',
    'wickets_down',
    'balls_remaining',
    'wickets_remaining',
    'current_run_rate',
    'required_run_rate',
    'target_score'
]

X = df[features].apply(pd.to_numeric, errors='coerce')
X = X.replace([float('inf'), float('-inf')], 0)
X = X.fillna(0)

y = (df['batting_team'] == df['winner']).astype(int)

# %% [markdown]
# # 3.train-test split

# %%
from sklearn.model_selection import train_test_split


# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42
)

# %% [markdown]
# # 4.Train the model

# %%
model.fit(X_train, y_train)

print("Model training completed successfully!")
# Out:
# Model training completed successfully!

# %% [markdown]
# # 5.Make Predictions

# %%
y_pred = model.predict(X_test)

print(y_pred[:10])
# Out:
# [0 1 1 1 1 0 1 0 0 0]

# %% [markdown]
# # 6.Check model accuracy

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.7342966517496091
